# %% [markdown]
# <a href="https://colab.research.google.com/github/Mtpiercenokc/MITIDSS/blob/main/Untitled_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import scipy.stats as stats

# %%
mu, sigma = 5, 1.3

x_bar = 5.25

test_stat = (x_bar - mu) / (sigma / np.sqrt(45))
test_stat
# Out:
# 1.2900392177883402

# %%
from scipy.stats import norm

x = np.linspace(-4, 4, 100)
plt.plot(x, norm.pdf(x, 0, 1))
plt.avxline(x = test_stat, c = 'r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-5b6a6000114a> in <cell line: 5>()
#       3 x = np.linspace(-4, 4, 100)
#       4 plt.plot(x, norm.pdf(x, 0, 1))
# ----> 5 plt.avxline(x = test_stat, c = 'r')
#       6 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'avxline'

# %%
1 - norm.cdf(test_stat)
# Out:
# 0.09851852092578695

# %%
from scipy.stats import norm

crit = norm.ppf(1-0.05)
crit
# Out:
# 1.6448536269514722

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10 , 10, 50)
y = np.sin(x)
plt.plot(x, y, marker="x")
plt.show()
